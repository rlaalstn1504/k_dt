# %%
import pandas as pd

# %%
question_log = pd.read_csv('log.csv')# csv에 저장된 로그 확인(질문, 답변, 시간)
question_log
# Out:
#                              question  \
# 0                      넘어졌는데 무릎에 피가나요
# 1                              배가 아파요
# 2                             두피가 아파요
# 3                     비 오는 날에 무릎이 아파요
# 4                      몸에 열이 나는 거 같아요
# 5                             발바닥이 아픔
# 6                   치아 안에 신경이 죽은듯 합니다
# 7   2주간 기침을 계속하고 콧물도 많이 나와요. 어떻게 할까요?
# 8                             머리가 아파요
# 9        스트림릿을 활용한 데이터 시각화 기능도 보고 싶어요
# 10  2주간 기침을 계속하고 콧물도 많이 나와요. 어떻게 할까요?
#
#                                                answer                 time
# 0   넘어진 후 무릎에서 피가 난다면, 피부가 찰과상을 입었을 가능성이 높습니다. 이는 ...  2024-06-30 09:08:37
# 1   배가 아프다고 하셨군요. 불편함을 느끼시는 정확한 위치와 통증의 성격(예: 찌르는 ...  2024-06-30 09:24:43
# 2   두피가 아프다고 느끼시는군요. 두피 통증은 여러 가지 이유로 발생할 수 있습니다. ...  2024-06-30 09:24:47
# 3   비 오는 날에 무릎 통증을 느낀다면, 이는 날씨 변화가 관절 통증에 영향을 줄 수 ...  2024-06-30 09:42:52
# 4   증상에 대해 말씀해주셔서 감사합니다. 몸에 열이 나는 것은 다양한 원인으로 인해 발...  2024-06-30 10:21:37
# ...

# %%
reservation_log = pd.read_csv('reserve.csv') # csv에 저장된 로그 확인(예약한 환자 명단)
reservation_log
# Out:
#   name   age  gender      time
# 0  김민수    30       남  09:00 AM
# 1  김민수    30       남  09:00 AM
# 2    김    45       남  09:00 AM
# 3  윤__    20       남  09:00 AM
# 4  좌__    37       남  09:00 AM
# 5  오__    35       남  09:00 AM
# 6  NaN    32       남  09:00 AM
